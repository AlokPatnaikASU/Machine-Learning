# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/placement.csv")

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df=df.iloc[:,1:]
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

plt.scatter(df["cgpa"],df["iq"],c=df["placement"])

# %%
x=df.iloc[:,:2]
y=df.iloc[:,2]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 27   6.0  124.0
# 66   6.9   96.0
# 84   5.7  169.0
# 48   6.6  138.0
# 89   4.9  151.0
# ..   ...    ...
# 5    7.1   48.0
# 57   6.5  130.0
# 17   3.3  183.0
# 68   4.0   75.0
# 54   6.4  141.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 27    1
# 66    1
# 84    0
# 48    1
# 89    0
#      ..
# 5     1
# 57    1
# 17    0
# 68    0
# 54    1
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 74   6.7  154.0
# 50   3.5  233.0
# 23   4.7   87.0
# 51   4.8  141.0
# 3    7.4  132.0
# 58   8.0   79.0
# 67   5.0  118.0
# 33   6.0  149.0
# 79   6.5   90.0
# 45   6.0   66.0

# %%
y_test
# Out:
# 74    1
# 50    0
# 23    0
# 51    0
# 3     1
# 58    1
# 67    0
# 33    0
# 79    1
# 45    1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)
x_train
# Out:
# array([[-0.00497109,  0.01456464],
#        [ 0.80034552, -0.70509973],
#        [-0.27340996,  1.17116808],
#        [ 0.53190665,  0.37439682],
#        [-0.98924695,  0.7085267 ],
#        [ 0.3529474 , -0.19105375],
#        [ 0.08450853,  0.22018303],
#        [ 0.88982514, -0.29386295],
#        [ 0.88982514, -1.52757328],
#        [ 0.97930477,  0.7085267 ],
#        [ 1.874101  ,  0.6571221 ],
#        [ 0.08450853, -0.52518364],
#        [-0.98924695,  1.86513014],
#        [-0.27340996,  0.22018303],
#        [-0.27340996,  0.42580141],
#        [ 0.08450853, -1.09063421],
#        [-0.8102877 ,  1.35108417],
#        [-1.25768582,  0.58001521],
#        [ 0.80034552,  0.37439682],
#        [-0.8102877 , -1.47616869],
#        [-0.72080808, -0.85931352],
#        [-0.00497109, -0.55088593],
#        [-1.07872657,  1.17116808],
#        [ 1.33722326,  0.88844279],
#        [-0.98924695,  0.27158762],
#        [-0.98924695, -0.08824456],
#        [-0.54184883,  0.29728992],
#        [-1.16820619, -0.06254226],
#        [-0.8102877 ,  0.11737383],
#        [-1.52612469,  1.96793933],
#        [ 1.15826401, -0.96212271],
#        [ 1.33722326,  0.16877843],
#        [ 0.7108659 , -0.29386295],
#        [ 1.874101  ,  1.09406118],
#        [-0.54184883, -0.24245835],
#        [ 1.42670288,  0.11737383],
#        [ 0.62138627,  1.50529796],
#        [ 0.08450853, -1.50187098],
#        [ 0.7108659 , -0.85931352],
#        [ 2.05306024,  1.14546578],
#        [ 0.7108659 ,  0.45150371],
#        [ 0.80034552,  0.40009912],
#        [ 2.23201949, -0.08824456],
#        [ 1.15826401, -1.88740546],
#        [-0.09445071, -0.44807674],
#        [-0.27340996,  0.50290831],
#        [-0.89976732, -0.83361122],
#        [-1.43664506,  0.6571221 ],
#        [-0.98924695, -1.60468018],
#        [-0.18393034,  1.09406118],
#        [-1.07872657,  1.01695428],
#        [ 0.53190665, -0.08824456],
#        [-0.89976732, -1.55327558],
#        [ 0.88982514,  1.32538187],
#        [-0.72080808,  2.5847945 ],
#        [ 0.44242703, -2.22153535],
#        [ 0.17398816, -0.26816065],
#        [-1.07872657, -0.29386295],
#        [-1.16820619, -1.83600087],
#        [ 0.88982514,  0.40009912],
#        [-0.54184883,  0.40009912],
#        [ 1.60566213, -0.24245835],
#        [ 0.26346778, -0.52518364],
#        [-1.79456356, -0.60229053],
#        [ 0.08450853,  0.83703819],
#        [ 0.26346778,  0.09167153],
#        [-0.72080808,  0.22018303],
#        [-0.63132845, -0.24245835],
#        [-1.88404318, -0.37096984],
#        [-1.43664506, -2.09302385],
#        [ 0.26346778,  0.11737383],
#        [-0.18393034,  0.47720601],
#        [-0.54184883, -0.42237444],
#        [ 0.88982514,  1.94223703],
#        [ 1.42670288, -0.88501582],
#        [ 0.7108659 , -0.01113766],
#        [-0.72080808,  0.96554969],
#        [ 1.33722326, -1.60468018],
#        [-0.98924695,  0.81133589],
#        [-0.00497109, -2.01591696],
#        [ 1.15826401, -0.19105375],
#        [ 0.44242703,  0.93984739],
#        [-0.63132845, -0.06254226],
#        [-0.72080808, -0.34526755],
#        [ 1.15826401,  0.34869452],
#        [ 0.97930477, -1.93881006],
#        [ 0.44242703,  0.16877843],
#        [-2.42092092,  1.53100026],
#        [-1.79456356, -1.244848  ],
#        [ 0.3529474 ,  0.45150371]])

# %%
x_test=scaler.transform(x_test)
x_test
# Out:
# array([[ 0.62138627,  0.7856336 ],
#        [-2.24196167,  2.81611519],
#        [-1.16820619, -0.93642041],
#        [-1.07872657,  0.45150371],
#        [ 1.24774364,  0.22018303],
#        [ 1.78462137, -1.1420388 ],
#        [-0.89976732, -0.13964916],
#        [-0.00497109,  0.6571221 ],
#        [ 0.44242703, -0.85931352],
#        [-0.00497109, -1.47616869]])

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
ypred=clf.predict(x_test)

# %%
y_test
# Out:
# 74    1
# 50    0
# 23    0
# 51    0
# 3     1
# 58    1
# 67    0
# 33    0
# 79    1
# 45    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,ypred)
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl',"wb"))
